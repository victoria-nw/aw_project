# %%
df = spark.read.parquet("abfss://landing@nyctaxiistorage.dfs.core.windows.net/yellow_tripdata_2023-01.parquet")
df.printSchema()

# %%
print(f"Row count: {df.count()}")

# %%
spark.sql("SHOW CATALOGS").show()
